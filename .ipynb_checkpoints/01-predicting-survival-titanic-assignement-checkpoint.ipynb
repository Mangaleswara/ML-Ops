# %% [markdown]
# ## Predicting Survival on the Titanic
#
# ### History
# Perhaps one of the most infamous shipwrecks in history, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 people on board. Interestingly, by analysing the probability of survival based on few attributes like gender, age, and social status, we can make very accurate predictions on which passengers would survive. Some groups of people were more likely to survive than others, such as women, children, and the upper-class. Therefore, we can learn about the society priorities and privileges at the time.
#
# ### Assignment:
#
# Build a Machine Learning Pipeline, to engineer the features in the data set and predict who is more likely to Survive the catastrophe.
#
# Follow the Jupyter notebook below, and complete the missing bits of code, to achieve each one of the pipeline steps.

# %%
import re

# to handle datasets
import pandas as pd
import numpy as np

# for visualization
import matplotlib.pyplot as plt

# to divide train and test set
from sklearn.model_selection import train_test_split

# feature scaling
from sklearn.preprocessing import StandardScaler

# to build the models
from sklearn.linear_model import LogisticRegression

# to evaluate the models
from sklearn.metrics import accuracy_score, roc_auc_score

# to persist the model and the scaler
import joblib

# to visualise al the columns in the dataframe
pd.pandas.set_option('display.max_columns', None)

# %% [markdown]
# ## Prepare the data set

# %%
# load the data - it is available open source and online

data = pd.read_csv('https://www.openml.org/data/get_csv/16826755/phpMYEkMl')

# display data
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# replace interrogation marks by NaN values

data = data.replace('?', np.nan)

# %%
# retain only the first cabin if more than
# 1 are available per passenger

def get_first_cabin(row):
    try:
        return row.split()[0]
    except:
        return np.nan
    
data['cabin'] = data['cabin'].apply(get_first_cabin)

# %%
# extracts the title (Mr, Ms, etc) from the name variable

def get_title(passenger):
    line = passenger
    if re.search('Mrs', line):
        return 'Mrs'
    elif re.search('Mr', line):
        return 'Mr'
    elif re.search('Miss', line):
        return 'Miss'
    elif re.search('Master', line):
        return 'Master'
    else:
        return 'Other'
    
data['title'] = data['name'].apply(get_title)

# %%
# cast numerical variables as floats

data['fare'] = data['fare'].astype('float')
data['age'] = data['age'].astype('float')

# %%
# drop unnecessary variables

data.drop(labels=['name','ticket', 'boat', 'body','home.dest'], axis=1, inplace=True)

# display data
data.head()
# Out:
#    pclass  survived     sex      age  sibsp  parch      fare cabin embarked  \
# 0       1         1  female  29.0000      0      0  211.3375    B5        S
# 1       1         1    male   0.9167      1      2  151.5500   C22        S
# 2       1         0  female   2.0000      1      2  151.5500   C22        S
# 3       1         0    male  30.0000      1      2  151.5500   C22        S
# 4       1         0  female  25.0000      1      2  151.5500   C22        S
#
#     title
# 0    Miss
# 1  Master
# 2    Miss
# 3      Mr
# 4     Mrs

# %%
# save the data set

data.to_csv('titanic.csv', index=False)

# %% [markdown]
# ## Data Exploration
#
# ### Find numerical and categorical variables

# %%
target = 'survived'

# %%
vars_num = data.select_dtypes(include=["int","float"]).columns.tolist()

vars_cat = data.select_dtypes(include=["object"]).columns.tolist()

print('Number of numerical variables: {}'.format(len(vars_num)))
print('Number of categorical variables: {}'.format(len(vars_cat)))
# Out:
# Number of numerical variables: 6
# Number of categorical variables: 4

# %% [markdown]
# ### Find missing values in variables

# %%
vars_num_data=data[vars_num]
vars_num_data.isnull().sum()
# Out:
# pclass        0
# survived      0
# age         263
# sibsp         0
# parch         0
# fare          1
# dtype: int64

# %%
vars_cat_data=data[vars_cat]
vars_cat_data.isnull().sum()
# Out:
# sex            0
# cabin       1014
# embarked       2
# title          0
# dtype: int64

# %% [markdown]
# ### Determine cardinality of categorical variables

# %%
for col in vars_cat:
    print(col, ':', vars_cat_data[col].nunique())
# Out:
# sex : 2
# cabin : 181
# embarked : 3
# title : 5

# %% [markdown]
# ### Determine the distribution of numerical variables

# %%
for col in vars_num:
    print(col, ':', vars_num_data[col].nunique())
# Out:
# pclass : 3
# survived : 2
# age : 98
# sibsp : 7
# parch : 8
# fare : 281

# %% [markdown]
# ## Separate data into train and test
#
# Use the code below for reproducibility. Don't change it.

# %%
X_train, X_test, y_train, y_test = train_test_split(
    data.drop('survived', axis=1),  # predictors
    data['survived'],  # target
    test_size=0.2,  # percentage of obs in test set
    random_state=0)  # seed to ensure reproducibility

X_train.shape, X_test.shape
# Out:
# ((1047, 9), (262, 9))

# %% [markdown]
# ## Feature Engineering
#
# ### Extract only the letter (and drop the number) from the variable Cabin

# %%
data['cabin_letter'] = data['cabin'].str.extract('([A-Za-z]+)')

# %%
data
# Out:
#       pclass  survived     sex      age  sibsp  parch      fare cabin  \
# 0          1         1  female  29.0000      0      0  211.3375    B5
# 1          1         1    male   0.9167      1      2  151.5500   C22
# 2          1         0  female   2.0000      1      2  151.5500   C22
# 3          1         0    male  30.0000      1      2  151.5500   C22
# 4          1         0  female  25.0000      1      2  151.5500   C22
# ...      ...       ...     ...      ...    ...    ...       ...   ...
# 1304       3         0  female  14.5000      1      0   14.4542   NaN
# 1305       3         0  female      NaN      1      0   14.4542   NaN
# 1306       3         0    male  26.5000      0      0    7.2250   NaN
# 1307       3         0    male  27.0000      0      0    7.2250   NaN
# 1308       3         0    male  29.0000      0      0    7.8750   NaN
#
#      embarked   title cabin_letter
# 0           S    Miss            B
# 1           S  Master            C
# ...

# %% [markdown]
# ### Fill in Missing data in numerical variables:
#
# - Add a binary missing indicator
# - Fill NA in original variable with the median

# %%
df=data
for col in df.columns:
    if df[col].isnull().any():
        df[col + '_Missing'] = df[col].isnull().astype(int)
for col in df.columns:
    if df[col].isnull().any() and df[col].dtype != 'object':
        median = df[col].median()
        df[col].fillna(median, inplace=True)

# %%
df
# Out:
#       pclass  survived     sex      age  sibsp  parch      fare cabin  \
# 0          1         1  female  29.0000      0      0  211.3375    B5
# 1          1         1    male   0.9167      1      2  151.5500   C22
# 2          1         0  female   2.0000      1      2  151.5500   C22
# 3          1         0    male  30.0000      1      2  151.5500   C22
# 4          1         0  female  25.0000      1      2  151.5500   C22
# ...      ...       ...     ...      ...    ...    ...       ...   ...
# 1304       3         0  female  14.5000      1      0   14.4542   NaN
# 1305       3         0  female  28.0000      1      0   14.4542   NaN
# 1306       3         0    male  26.5000      0      0    7.2250   NaN
# 1307       3         0    male  27.0000      0      0    7.2250   NaN
# 1308       3         0    male  29.0000      0      0    7.8750   NaN
#
#      embarked   title cabin_letter  age_Missing  fare_Missing  cabin_Missing  \
# ...

# %% [markdown]
# ### Replace Missing data in categorical variables with the string **Missing**

# %%
vars_cat_data.fillna('Missing', inplace=True)
# Out:
# C:\Users\Mangaleswara\AppData\Local\Temp\ipykernel_15644\3490530780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vars_cat_data.fillna('Missing', inplace=True)

# %%
vars_cat_data.isnull().sum()
# Out:
# sex         0
# cabin       0
# embarked    0
# title       0
# dtype: int64

# %% [markdown]
# ### Remove rare labels in categorical variables
#
# - remove labels present in less than 5 % of the passengers

# %%
for col in df.columns:
    if df[col].dtype == 'object':
        freq = df[col].value_counts(normalize=True)
        rare_labels = freq[freq < 0.05].index
        df[col] = df[col].apply(lambda x: 'Rare' if x in rare_labels else x)

# %%
df
# Out:
#       pclass  survived     sex      age  sibsp  parch      fare cabin  \
# 0          1         1  female  29.0000      0      0  211.3375  Rare
# 1          1         1    male   0.9167      1      2  151.5500  Rare
# 2          1         0  female   2.0000      1      2  151.5500  Rare
# 3          1         0    male  30.0000      1      2  151.5500  Rare
# 4          1         0  female  25.0000      1      2  151.5500  Rare
# ...      ...       ...     ...      ...    ...    ...       ...   ...
# 1304       3         0  female  14.5000      1      0   14.4542   NaN
# 1305       3         0  female  28.0000      1      0   14.4542   NaN
# 1306       3         0    male  26.5000      0      0    7.2250   NaN
# 1307       3         0    male  27.0000      0      0    7.2250   NaN
# 1308       3         0    male  29.0000      0      0    7.8750   NaN
#
#      embarked title cabin_letter  age_Missing  fare_Missing  cabin_Missing  \
# ...

# %% [markdown]
# # Performing Imputation on variables before proceeding

# %%
data.isnull().sum()*100/len(data)
# Out:
# pclass                   0.000000
# survived                 0.000000
# sex                      0.000000
# age                      0.000000
# sibsp                    0.000000
# parch                    0.000000
# fare                     0.000000
# cabin                   77.463713
# embarked                 0.152788
# title                    0.000000
# cabin_letter            77.463713
# age_Missing              0.000000
# fare_Missing             0.000000
# cabin_Missing            0.000000
# embarked_Missing         0.000000
# cabin_letter_Missing     0.000000
# dtype: float64

# %% [markdown]
# Performing mode imputation for embarked

# %%
X_train[X_train['embarked'].isnull()]
# Out:
#      pclass     sex   age  sibsp  parch  fare cabin embarked title
# 284       1  female  62.0      0      0  80.0   B28      NaN   Mrs
# 168       1  female  38.0      0      0  80.0   B28      NaN  Miss

# %%
X_train['embarked'] = X_train['embarked'].fillna(X_train['embarked'].mode()[0])
X_test['embarked'] = X_test['embarked'].fillna(X_train['embarked'].mode()[0])

# %%
X_train[X_train['embarked'].isnull()]
# Out:
# Empty DataFrame
# Columns: [pclass, sex, age, sibsp, parch, fare, cabin, embarked, title]
# Index: []

# %%
X_train.columns
# Out:
# Index(['pclass', 'sex', 'age', 'sibsp', 'parch', 'fare', 'cabin', 'embarked',
#        'title'],
#       dtype='object')

# %%
X_train.isnull().sum()
# Out:
# pclass        0
# sex           0
# age         206
# sibsp         0
# parch         0
# fare          1
# cabin       803
# embarked      0
# title         0
# dtype: int64

# %%
age_mapper = X_train.groupby('title')['age'].mean().to_dict()

# %%
X_train['age_f'] = np.where(X_train['age'].isnull(),X_train['title'].map(age_mapper),X_train['age'])

# %%
X_test['age_f'] = np.where(X_test['age'].isnull(),X_test['title'].map(age_mapper),X_test['age'])

# %%
X_train['age_f'] = X_train['age_f'].fillna(X_train['age'].mean())
X_test['age_f'] = X_test['age_f'].fillna(X_test['age'].mean())

# %%
X_train['age_null'] = np.where(X_train['age'].isnull(),1,0)
X_test['age_null'] = np.where(X_test['age'].isnull(),1,0)

# %%
X_train['cabin_f'] = X_train['cabin'].str[0]
X_test['cabin_f'] = X_test['cabin'].str[0]

# %%
X_train.isnull().sum()
# Out:
# pclass        0
# sex           0
# age         206
# sibsp         0
# parch         0
# fare          1
# cabin       803
# embarked      0
# title         0
# age_f         0
# age_null      0
# cabin_f     803
# dtype: int64

# %%
X_test.isnull().sum()
# Out:
# pclass        0
# sex           0
# age          57
# sibsp         0
# parch         0
# fare          0
# cabin       211
# embarked      0
# title         0
# age_f         0
# age_null      0
# cabin_f     211
# dtype: int64

# %%
median_value = X_train['fare'].median()
X_train['fare'].fillna(median_value, inplace=True)

# %%
X_train.isnull().sum()
# Out:
# pclass        0
# sex           0
# age         206
# sibsp         0
# parch         0
# fare          0
# cabin       803
# embarked      0
# title         0
# age_f         0
# age_null      0
# cabin_f     803
# dtype: int64

# %%
X_train.drop(['age', 'cabin','cabin_f'], axis=1, inplace=True)

# %%
X_train.isnull().sum()
# Out:
# pclass      0
# sex         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# title       0
# age_f       0
# age_null    0
# dtype: int64

# %%
X_test.drop(['age', 'cabin','cabin_f'], axis=1, inplace=True)

# %%
X_test.isnull().sum()
# Out:
# pclass      0
# sex         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# title       0
# age_f       0
# age_null    0
# dtype: int64

# %% [markdown]
# ### Perform one hot encoding of categorical variables into k-1 binary variables
#
# - k-1, means that if the variable contains 9 different categories, we create 8 different binary variables
# - Remember to drop the original categorical variable (the one with the strings) after the encoding

# %%
X_train=pd.get_dummies(X_train)
X_test=pd.get_dummies(X_test)

# %%
X_train
# Out:
#       pclass  sibsp  parch      fare      age_f  age_null  sex_female  \
# 1118       3      0      0    7.9250  25.000000         0           0
# 44         1      0      0  134.5000  41.000000         0           1
# 1072       3      0      0    7.7333  31.995671         1           0
# 1130       3      0      0    7.7750  18.000000         0           1
# 574        2      1      0   21.0000  29.000000         0           0
# ...      ...    ...    ...       ...        ...       ...         ...
# 763        3      1      2   20.5750   0.166700         0           1
# 835        3      0      0    8.0500  31.995671         1           0
# 1216       3      0      0    7.7333  22.757663         1           1
# 559        2      0      0   36.7500  20.000000         0           1
# 684        3      1      1   15.5000  32.000000         0           1
#
#       sex_male  embarked_C  embarked_Q  embarked_S  title_Master  title_Miss  \
# ...

# %% [markdown]
# ### Scale the variables
#
# - Use the standard scaler from Scikit-learn

# %%
features=X_train.columns

# %%
X_train_for_modelling = X_train[features]
X_test_for_modelling = X_test[features]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

scaler.fit(X_train_for_modelling)
X_train_for_modelling = scaler.transform(X_train_for_modelling)
X_train_for_modelling = pd.DataFrame(X_train_for_modelling, columns= features)

X_test_for_modelling = scaler.transform(X_test_for_modelling)
X_test_for_modelling = pd.DataFrame(X_test_for_modelling, columns= features)

X_test_for_modelling.head()
# Out:
#      pclass     sibsp     parch      fare     age_f  age_null  sex_female  \
# 0  0.835808 -0.478911 -0.455423 -0.505353  0.616814 -0.494921   -0.761042
# 1 -0.353174 -0.478911  0.727773 -0.248980 -0.704917 -0.494921    1.313987
# 2 -0.353174  0.434422 -0.455423 -0.131595  0.927810 -0.494921   -0.761042
# 3  0.835808 -0.478911 -0.455423 -0.376148  0.149984  2.020526   -0.761042
# 4 -0.353174 -0.478911 -0.455423 -0.043556 -0.393922 -0.494921   -0.761042
#
#    sex_male  embarked_C  embarked_Q  embarked_S  title_Master  title_Miss  \
# 0  0.761042   -0.493425   -0.319539    0.636686     -0.216795   -0.500895
# 1 -1.313987   -0.493425   -0.319539    0.636686     -0.216795    1.996425
# 2  0.761042   -0.493425   -0.319539    0.636686     -0.216795   -0.500895
# 3  0.761042   -0.493425   -0.319539    0.636686     -0.216795   -0.500895
# 4  0.761042   -0.493425   -0.319539    0.636686     -0.216795   -0.500895
#
#    title_Mr  title_Mrs  title_Other
# 0  0.869892  -0.435629    -0.162698
# ...

# %% [markdown]
# ## Train the Logistic Regression model
#
# - Set the regularization parameter to 0.0005
# - Set the seed to 0

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(C=0.0005, random_state=0)
model.fit(X_train_for_modelling, y_train)

train_predictions = model.predict(X_train_for_modelling)
test_predictions = model.predict(X_test_for_modelling)

# %% [markdown]
# ## Make predictions and evaluate model performance
#
# Determine:
# - roc-auc
# - accuracy
#
# **Important, remember that to determine the accuracy, you need the outcome 0, 1, referring to survived or not. But to determine the roc-auc you need the probability of survival.**

# %%
from sklearn import metrics
train_accuracy = metrics.accuracy_score(y_train, train_predictions)
test_accuracy = metrics.accuracy_score(y_test, test_predictions)
train_accuracy, test_accuracy
# Out:
# (0.7297039159503342, 0.732824427480916)

# %% [markdown]
# The test acuuracy is **73.27%**

# %% [markdown]
# # ROC Curve with score

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

# y_true contains the true labels, y_pred contains the predicted labels
fpr, tpr, thresholds = roc_curve(y_test, test_predictions)
roc_auc = roc_auc_score(y_test, test_predictions)

# plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--', label='Random guess')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# That's it! Well done
#
# **Keep this code safe, as we will use this notebook later on, to build production code, in our next assignement!!**
